# %% [markdown]
# # **SUBSCRIBE to the [channel](https://www.youtube.com/user/19daredevill?sub_confirmation=1) to learn cool things**

# %% [markdown]
# **Step 1 : Clone yolov5 repository**

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13176, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 13176 (delta 6), reused 12 (delta 4), pack-reused 13156
# Receiving objects: 100% (13176/13176), 12.02 MiB | 28.23 MiB/s, done.
# Resolving deltas: 100% (9155/9155), done.

# %% [markdown]
# **Step 2: Change Directory to yolov5**

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %% [markdown]
# **Step 3: Install Dependencies**

# %%
# !pip install -U -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 60.5 MB 67 kB/s
# ...
#      |████████████████████████████████| 4.3 MB 53.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 48.4 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 19.6 MB/s
# ...
#      |████████████████████████████████| 930 kB 45.8 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: matplotlib
# ...

# %% [markdown]
# **Step 4: Run Object Detection on Images. Provide image path. Upload image in the inference/images/ folder**

# %%
# !python detect.py --source ./inference/images/zidane.jpg --weights yolov5s.pt --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=./inference/images/zidane.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-174-gc4cb7c6 torch 1.11.0+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/yolov5/inference/images/zidane.jpg: 384x640 1 person, Done. (0.296s)
# Speed: 4.2ms pre-process, 296.3ms inference, 13.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
#Verify IMG 
image = cv2.imread("runs/detect/exp4/zidane.jpg")
assert not isinstance(image,type(None)), 'image not found'

# %% [markdown]
# **Step 5: Display image in colab**

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread("runs/detect/exp4/zidane.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# !python detect.py --source ./inference/images/cat_doge.jpg --weights yolov5s.pt --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=./inference/images/cat_doge.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-174-gc4cb7c6 torch 1.11.0+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/yolov5/inference/images/cat_doge.jpg: 448x640 2 cats, Done. (0.362s)
# Speed: 6.1ms pre-process, 362.2ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread("runs/detect/exp6/cat_doge.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# **Object Detection on Videos. Create a folder under inference/ called "videos", under which you can upload the video file and then provide the file path below**

# %%
# !python detect.py --source inference/videos/cats1.mp4 --weights yolov5s.pt --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=inference/videos/cats1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-174-gc4cb7c6 torch 1.11.0+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/1398) /content/yolov5/inference/videos/cats1.mp4: 640x384 Done. (0.323s)
# video 1/1 (2/1398) /content/yolov5/inference/videos/cats1.mp4: 640x384 Done. (0.275s)
# video 1/1 (3/1398) /content/yolov5/inference/videos/cats1.mp4: 640x384 Done. (0.284s)
# video 1/1 (4/1398) /content/yolov5/inference/videos/cats1.mp4: 640x384 Done. (0.265s)
# ...
